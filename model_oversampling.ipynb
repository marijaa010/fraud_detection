# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import roc_curve, auc

from imblearn.over_sampling import SMOTE

from keras.layers import Input, Dense
from keras.models import Model

# %%
data = pd.read_csv('creditcard.csv')

# %%
data.shape
# Out:
# (284807, 30)

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.473120e-16  8.042109e-16  5.282512e-16  4.456271e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.426896e-15  1.701640e-15 -3.662252e-16 -1.217809e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
data = data.drop('Time', axis = 1)

X = data.drop('Class', axis=1)
y = data['Class']

sm = SMOTE(random_state=42)
X_resampled, y_resampled = sm.fit_resample(X, y)

# %%
oversampled_data = pd.concat([X_resampled, y_resampled], axis=1)

# %%
data["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
oversampled_data["Class"].value_counts()
# Out:
# 0    284315
# 1    284315
# Name: Class, dtype: int64

# %%
fraud_data = oversampled_data[oversampled_data["Class"] == 1]
non_fraud_data = oversampled_data[oversampled_data["Class"] == 0]

# %%
X_non_fraud = non_fraud_data.drop(columns=["Class"])
y_non_fraud = non_fraud_data["Class"]

X_train, X_non_fraud_test, y_train, y_non_fraud_test = train_test_split(X_non_fraud, y_non_fraud, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (227452, 29)

# %%
y_train.shape
# Out:
# (227452,)

# %%
X_test = pd.concat([X_non_fraud_test, fraud_data.drop(columns=["Class"])], axis=0)
y_test = pd.concat([y_non_fraud_test, fraud_data["Class"]], axis=0)

# %%
y_train.value_counts()
# Out:
# 0    227452
# Name: Class, dtype: int64

# %%
y_test.value_counts()
# Out:
# 1    284315
# 0     56863
# Name: Class, dtype: int64

# %%
scaler = StandardScaler()

X_train["Amount"] = scaler.fit_transform(X_train["Amount"].values.reshape(-1, 1))
X_test["Amount"] = scaler.transform(X_test["Amount"].values.reshape(-1, 1))

# %%
input_layer = Input(shape=(X_train.shape[1],))

# %%
encoded = Dense(128, activation='relu')(input_layer)
encoded = Dense(64, activation='relu')(encoded)
encoded = Dense(32, activation='relu')(encoded)

# %%
decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(decoded)
decoded = Dense(X_train.shape[1], activation='sigmoid')(decoded)

# %%
autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 29)]              0
#
#  dense (Dense)               (None, 128)               3840
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 64)                2112
#
#  dense_4 (Dense)             (None, 128)               8320
#
#  dense_5 (Dense)             (None, 29)                3741
#
# =================================================================
# Total params: 28,349
# Trainable params: 28,349
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.fit(X_train, X_train, epochs=50, batch_size=256, shuffle=True)
# Out:
# Epoch 1/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.8502
# Epoch 2/50
# 889/889 [==============================] - 1s 2ms/step - loss: 0.8000
# Epoch 3/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7881
# Epoch 4/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7872
# Epoch 5/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7867
# Epoch 6/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7863
# Epoch 7/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7776
# Epoch 8/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7750
# Epoch 9/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7645
# Epoch 10/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7612
# Epoch 11/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7606
# Epoch 12/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7604
# Epoch 13/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7603
# Epoch 14/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7602
# Epoch 15/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7600
# Epoch 16/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7600
# Epoch 17/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7599
# Epoch 18/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7599
# Epoch 19/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7598
# Epoch 20/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7598
# Epoch 21/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7598
# Epoch 22/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7598
# Epoch 23/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7597
# Epoch 24/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7596
# Epoch 25/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7596
# Epoch 26/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7596
# Epoch 27/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7595
# Epoch 28/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7595
# Epoch 29/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7595
# Epoch 30/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7595
# Epoch 31/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7595
# Epoch 32/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7594
# Epoch 33/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7595
# Epoch 34/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7594
# Epoch 35/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7594
# Epoch 36/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7594
# Epoch 37/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7594
# Epoch 38/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7595
# Epoch 39/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7593
# Epoch 40/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7594
# Epoch 41/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7593
# Epoch 42/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7593
# Epoch 43/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7593
# Epoch 44/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7593
# Epoch 45/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7593
# Epoch 46/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7572
# Epoch 47/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7539
# Epoch 48/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7539
# Epoch 49/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7539
# Epoch 50/50
# 889/889 [==============================] - 2s 2ms/step - loss: 0.7538

# %%
reconstructed = autoencoder.predict(X_test)

mse = ((X_test - reconstructed) ** 2).mean(axis=1)

mse = np.mean(np.power(X_test - reconstructed, 2), axis=1)
error_df = pd.DataFrame({'Reconstruction_error': mse,
                        'True_class': y_test})
error_df
# Out:
# 10662/10662 [==============================] - 9s 872us/step
#         Reconstruction_error  True_class
# 138028              0.150573           0
# 63099               0.086377           0
# 73411               0.482522           0
# 164247              0.272644           0
# 148999              0.778669           0
# ...                      ...         ...
# 568625             24.296767           1
# 568626              4.148815           1
# 568627              3.093094           1
# 568628              1.085608           1
# 568629             10.905795           1
#
# [341178 rows x 2 columns]

# %%
error_df.describe()
# Out:
#        Reconstruction_error     True_class
# count         341178.000000  341178.000000
# mean              20.890164       0.833333
# std               34.133898       0.372679
# min                0.026702       0.000000
# 25%                1.342269       1.000000
# 50%                6.227816       1.000000
# 75%               19.649313       1.000000
# max             1862.369540       1.000000

# %%
num_thresholds = 10

n_rows = 5
n_cols = num_thresholds // n_rows

fig, axes = plt.subplots(n_rows, n_cols, figsize=(9, 12))

for i, ax in enumerate(axes.ravel()):
    if i < num_thresholds:
        threshold = (i + 20) / 10.0
        y_pred = [1 if error > threshold else 0 for error in mse]
        confusion = confusion_matrix(y_test, y_pred)
        
        sns.heatmap(confusion, annot=True, fmt="d", cmap="Reds", cbar=False, ax=ax)
        ax.set_xlabel("Predicted")
        ax.set_ylabel("Actual")
        ax.set_title(f"Threshold = {threshold}")
    else:
        ax.axis("off")

plt.tight_layout()
plt.show()

# %%
threshold = 2.9

# %%
y_pred = [1 if error > threshold else 0 for error in mse]
confusion = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, fmt="d", cmap="Reds", cbar=False)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.8378822784587517

# %%
report = classification_report(y_test, y_pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.97      0.67     56863
#            1       0.99      0.81      0.89    284315
#
#     accuracy                           0.84    341178
#    macro avg       0.75      0.89      0.78    341178
# weighted avg       0.91      0.84      0.86    341178

# %%
fpr, tpr, thresholds = roc_curve(y_test, mse)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

# %%
groups = error_df.groupby('True_class')
fig, ax = plt.subplots(figsize=(14, 8))

for name, group in groups:
    ax.plot(group.index, group.Reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1],
          colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")

plt.ylim(0, 300);

plt.show();

# %%
groups = error_df.groupby('True_class')
fig, ax = plt.subplots(figsize=(14, 8))

for name, group in groups:
    ax.plot(group.index, group.Reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1],
          colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")

plt.ylim(0, 150);

plt.show();

# %%
groups = error_df.groupby('True_class')
fig, ax = plt.subplots(figsize=(14, 8))

for name, group in groups:
    ax.plot(group.index, group.Reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1],
          colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")

plt.ylim(0, 50);

plt.show();

# %%
groups = error_df.groupby('True_class')
fig, ax = plt.subplots(figsize=(14, 8))

for name, group in groups:
    ax.plot(group.index, group.Reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1],
          colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")

plt.ylim(0, 20);

plt.show();
